# %%
import matplotlib.pyplot as pl
pl.plot([1,2,3,4])
pl.plot([2,3,4,5])
pl.ylabel("parallel")
pl.show()

# %%
import matplotlib.pyplot as pl

pl.plot([1,2,3,4])
pl.plot([4,3,2,1])
pl.ylabel("intersect")
pl.show()

# %%
import matplotlib.pyplot as pl

pl.plot([1,2,3,4])
pl.plot([1,2,3,4])
pl.ylabel("same line")
pl.show()

# %%
import matplotlib.pyplot as pl

pl.plot([5,6,7,8],[2,3,4,5])
pl.plot([5,6,7,8],[10,9,8,7])
pl.ylabel("intersect")
pl.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as npr
import math

#2x1 + x2 = 3
#--> x2 = 3-2x1
#x1 - 3x2 = -2
#x2= 2+x1/3

x=np.arange(-6,6,1)
y1=np.array(3-(2*x))
y2=np.array((2+x)/3)



plt.plot(x,y1)
plt.plot(x,y2)

plt.ylabel("primeira resolução de sistemas lineares")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as npr
import math

#2x1 + x2 = 3
#--> x2 = 3-2x1
#4x1 + 2x2 = 2
#x2= (2-(4*x1))/2

x=np.arange(-6,6,1)
y1=np.array(3-(2*x))
y2=np.array((2-(4*x))/2)



plt.plot(x,y1)
plt.plot(x,y2)

plt.ylabel("nenhuma solução")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as npr
import math

#2x1 + x2 = 3
#--> x2 = 3-2x1
#4x1 + 2x2 = 2
#x2= (2-(4*x1))/2

x=np.arange(-6,6,1)
y1=np.array(3-(2*x))
y2=np.array((6-(4*x))/2)



plt.plot(x,y1)
plt.plot(x,y2)

plt.ylabel("infinitas soluções")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as npr
import math

#representação em graficos separados

def matriz(a,v):

    r=np.matmul(a.data,v)
    print(r)
    return r


a= np.matrix([[1,3], [-2,5]])
v= np.array([3,4])

y1=np.array(v[0]*x)
y2=np.array(-v[1]*x)


plt.figure(1)
plt.subplot(211)
plt.plot(x,y1)
plt.plot(x,y2)

r= matriz(a,v)

x= np.arange(0,6,1)
y1=np.array(r[0]*x)
y2=np.array(-r[1]*x)

plt.subplot(212)
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()
# Out:
# [15 14]

# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as npr
import math

#representação juntos em um unico gráfico

def matriz(a,v):

    r=np.matmul(a.data,v)
    print(r)
    return r


a= np.matrix([[1,3], [-2,5]])
v= np.array([3,4])

y1=np.array(v[0]*x)
y2=np.array(-v[1]*x)



plt.plot(x,y1)
plt.plot(x,y2)

r= matriz(a,v)

x= np.arange(0,6,1)
y1=np.array(r[0]*x)
y2=np.array(-r[1]*x)


plt.plot(x,y1)
plt.plot(x,y2)
plt.show()
# Out:
# [15 14]
